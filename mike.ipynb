# %%
import pandas as pd
print(pd.__version__)
# series in pandas
a=[4,5,6,7]
b=[8,9,1,4]
table=pd.Series(a,index=["day1","day2","day3","day4"])
print(table)
# Out:
# 1.3.5
# day1    4
# day2    5
# day3    6
# day4    7
# dtype: int64

# %%
a={
    "new":[4,5,6,7]
}

table=pd.DataFrame(a,index=["day1","day2","day3","day4"])
print(table)
# Out:
#       new
# day1    4
# day2    5
# day3    6
# day4    7

# %%
import matplotlib.pyplot as plt 
import pandas as pd
with open("data.csv") as data:
    contents=data.read()
# print(contents)

contents
contents=pd.read_csv("data.csv").to_string()
# print(contents)
plt.plot(contents)
plt.show()
